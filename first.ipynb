# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# This cell does

# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
