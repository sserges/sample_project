# %%
import numpy as np

# %% [markdown]
# ## DataTypes and Attributes

# %%
# NumPy's main datatype is ndarray

# %%
a1 = np.array([1, 2, 3])

# %%
a1
# Out:
# array([1, 2, 3])

# %%
a2 = np.array([[1, 2, 3], [4, 5, 6.5]])

# %%
a1.shape
# Out:
# (3,)

# %%
a2.shape
# Out:
# (2, 3)

# %%
a1.ndim
# Out:
# 1

# %%
a2.ndim
# Out:
# 2

# %%
a1.dtype
# Out:
# dtype('int64')

# %%
a2.dtype
# Out:
# dtype('float64')

# %%
a1.size
# Out:
# 3

# %%
a2.size
# Out:
# 6

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
# Create a DataFrame from NumPy array
import pandas as pd
df = pd.DataFrame(a2)

# %%
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.5

# %% [markdown]
# ## Creating arrays

# %%
ones = np.ones((2, 3))

# %%
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones.dtype
# Out:
# dtype('float64')

# %%
type(ones)
# Out:
# numpy.ndarray

# %%
zeros = np.zeros((2, 3))

# %%
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array = np.arange(0, 10, 2)

# %%
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0, 10, size=(3, 5))

# %%
random_array
# Out:
# array([[8, 7, 3, 1, 6],
#        [1, 7, 2, 6, 8],
#        [8, 7, 0, 4, 0]], dtype=int32)

# %%
random_array.size
# Out:
# 15

# %%
len(random_array)
# Out:
# 3

# %%
random_array.shape
# Out:
# (3, 5)

# %%
random_array_2 = np.random.random((5, 3))

# %%
random_array_2
# Out:
# array([[0.73578618, 0.13654223, 0.74131173],
#        [0.24156889, 0.70967862, 0.19892681],
#        [0.4765054 , 0.0758437 , 0.76005524],
#        [0.5929158 , 0.65737191, 0.13009607],
#        [0.75721644, 0.67162725, 0.52942205]])

# %%
random_array_3 = np.random.rand(5, 3)

# %%
random_array_3
# Out:
# array([[0.75987115, 0.67912166, 0.49617909],
#        [0.32972486, 0.82252374, 0.40203427],
#        [0.41301779, 0.4821006 , 0.75108204],
#        [0.84066001, 0.5195795 , 0.64629214],
#        [0.87190469, 0.12224348, 0.3453536 ]])

# %%
# Pseudo-random numbers
np.random.seed()
